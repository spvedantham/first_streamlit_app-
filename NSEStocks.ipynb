# %% [markdown]
# <a href="https://colab.research.google.com/github/spvedantham/first_streamlit_app-/blob/main/NSEStocks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nselib

# %%
import nselib
from nselib import capital_market

# %%
nselib.trading_holiday_calendar()
# Out:
#                                    Product  tradingDate  ... morning_session evening_session
# 0                          Corporate Bonds  22-Jan-2024  ...            None            None
# 1                          Corporate Bonds  26-Jan-2024  ...            None            None
# 2                          Corporate Bonds  19-Feb-2024  ...            None            None
# 3                          Corporate Bonds  08-Mar-2024  ...            None            None
# 4                          Corporate Bonds  25-Mar-2024  ...            None            None
# ..                                     ...          ...  ...             ...             ...
# 16  Securities Lending & Borrowing Schemes  12-Oct-2024  ...            None            None
# 17  Securities Lending & Borrowing Schemes  01-Nov-2024  ...            None            None
# 18  Securities Lending & Borrowing Schemes  02-Nov-2024  ...            None            None
# ...

# %%
df = capital_market.bhav_copy_equities('24-10-2024')
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
df.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-ed50dd223777> in <cell line: 1>()
# ----> 1 df.shape()
#       2
#
# TypeError: 'tuple' object is not callable
